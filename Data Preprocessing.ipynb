# %% [markdown]
# ## Basic imports

# %%
# Basics Imports
`
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# To Avoid warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading the data

# %%
#Read data through excel
df = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')

# %%
#Displaying max columns and dataframe 
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %% [markdown]
# ## Information about data

# %%
#shape of the data
df.shape
# Out:
# (1200, 28)

# %%
#information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
# Statistical information about the data
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# ## Checking Null values

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %% [markdown]
# ## Distribution of numerical data

# %%
numcols = [col for col in df.columns if df[col].dtype!='object']

# %%
fig = plt.figure(figsize = (18,12), facecolor='white')
for i, col in enumerate(numcols[:-1], start = 1):
    ax = fig.add_subplot(5,4,i)
    sns.histplot(x = df[col],kde = True, ax = ax)
     
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights
# 1. The majority of employees fall between the ages of **25** to **40**.
# 2. Majority of people commute less than **8 miles** to the office.
# 3. Majority of people whose education level is **3**.
# 4. Minimum hourly rate is **30** and maximmum is **100**.
# 5. Mojority of people whose NumCompaniesWorked is **1**.
# 6. Maximum and Minimum % of hikes are **12 and 24**, while most people having 12 and least people having 24% hikes.
# 7. Maximum people have **5 t0 15%** of experiance in this company.
# 8. most people have passed **1 year** since their last promotion

# %% [markdown]
# ## Outliers in a dataset

# %%
def boxplots_custom(dataset, columns_list, rows, cols, suptitle):
    fig, axs = plt.subplots(rows, cols, sharey=True, figsize=(16, 10))
    fig.suptitle(suptitle, y=1, size=25)
    axs = axs.flatten()
    for i, data in enumerate(columns_list):
        sns.boxplot(data=dataset[data], orient='h', ax=axs[i], palette='deep')  
        axs[i].set_title(data + ', skewness is: ' + str(round(dataset[data].skew(axis=0, skipna=True), 2)))

boxplots_custom(dataset=df, columns_list=numcols, rows=5, cols=4, suptitle='Boxplots for each variable')
plt.tight_layout()
plt.show()

# %% [markdown]
# **The outlier columns in a dataset**
# 1. NumCompaniesWorked
# 2. TotalWorkExperienceInYears
# 3. TrainingTimesLastYear
# 4. ExperienceYearsAtThisCompany
# 5. ExperienceYearsInCurrentRole
# 6. YearsSinceLastPromotion
# 7. YearsWithCurrManager

# %% [markdown]
# **YearsSinceLastPromotion** is highly positive skewed we can address this issuse with following methods.
# 1. Logarithmic Transformation
# 2. Winsorization
# 3. Box-Cox Transformation
#
#
# To treat positive skewness and outliers of features, we use **Winsorization techinique** .

# %% [markdown]
# ## Treating outliers

# %%
outlier_list = ["NumCompaniesWorked", "TotalWorkExperienceInYears", "TrainingTimesLastYear",
             "ExperienceYearsAtThisCompany", "ExperienceYearsInCurrentRole",
             "YearsSinceLastPromotion", "YearsWithCurrManager"]

# %%
def winsorize_method(data, lower_percentile=10, upper_percentile=90):
    # Calculate percentiles
    lower_limit = np.percentile(data, lower_percentile)
    upper_limit = np.percentile(data, upper_percentile)
    
    # Replace outliers with the respective percentile values
    winsorized_data = np.where(data < lower_limit, lower_limit,
                               np.where(data > upper_limit, upper_limit, data))
    
    return winsorized_data

# Apply winsorize_method to each column in numcols
for col in numcols:
    df[col] = winsorize_method(df[col], lower_percentile=10, upper_percentile=90)

# %%
df.head()
# Out:
#   EmpNumber   Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000  32.0   Male           Marketing        Single            Sales
# 1  E1001006  47.0   Male           Marketing        Single            Sales
# 2  E1001007  40.0   Male       Life Sciences       Married            Sales
# 3  E1001009  41.0   Male     Human Resources      Divorced  Human Resources
# 4  E1001010  50.0   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely              10.0
# 1  Sales Executive           Travel_Rarely              14.0
# 2  Sales Executive       Travel_Frequently               5.0
# 3          Manager           Travel_Rarely              10.0
# 4  Sales Executive           Travel_Rarely              16.0
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                3.0                         4.0           55.0
# ...

# %%
df.to_excel('output_file.xlsx', index=False)
