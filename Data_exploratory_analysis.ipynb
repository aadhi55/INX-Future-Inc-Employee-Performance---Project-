# %% [markdown]
# ## Basic imports

# %%
# Basics Imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# To Avoid warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading dataset

# %%
df = pd.read_excel('output_file.xlsx')
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   50   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ## Information about data

# %%
# Statistical information about the data
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000          1200.0000
# mean     36.800000          8.831667             2.8575
# std       7.808808          7.484429             0.9881
# min      26.000000          1.000000             1.0000
# 25%      30.000000          2.000000             2.0000
# 50%      36.000000          7.000000             3.0000
# 75%      43.000000         14.000000             4.0000
# max      50.000000         23.000000             4.0000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      66.088333           2.696667
# std                      1.090599      19.075825           0.459890
# min                      1.000000      38.000000           2.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
from tabulate import tabulate
for col in df.columns[1:]:
    if df[col].dtype=='object':
        print(col)
        print(tabulate(df[col].value_counts().reset_index(), headers = ['Value', 'Count'], tablefmt = 'grid'))
# Out:
# Gender
# +----+---------+---------+
# |    | Value   |   Count |
# +====+=========+=========+
# |  0 | Male    |     725 |
# +----+---------+---------+
# |  1 | Female  |     475 |
# +----+---------+---------+
# EducationBackground
# +----+------------------+---------+
# |    | Value            |   Count |
# +====+==================+=========+
# |  0 | Life Sciences    |     492 |
# +----+------------------+---------+
# |  1 | Medical          |     384 |
# +----+------------------+---------+
# |  2 | Marketing        |     137 |
# +----+------------------+---------+
# |  3 | Technical Degree |     100 |
# +----+------------------+---------+
# |  4 | Other            |      66 |
# +----+------------------+---------+
# |  5 | Human Resources  |      21 |
# +----+------------------+---------+
# MaritalStatus
# +----+----------+---------+
# |    | Value    |   Count |
# +====+==========+=========+
# |  0 | Married  |     548 |
# +----+----------+---------+
# |  1 | Single   |     384 |
# ...

# %% [markdown]
# ### Countplot

# %%
catcols = [col  for col in df.columns[1:] if df[col].dtype == 'object']

# %%
# Finding the value_counts using countplot
plt.figure(figsize=(15, 8), facecolor='white') 
plotnumber = 1
for col in catcols:
    ax = plt.subplot(2, 4, plotnumber)  
    sns.countplot(x=df[col], ax=ax)
    plt.xticks(rotation=45, fontsize=10, ha='right')
    plt.xlabel(col)
    plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights from Exploratory Data Analysis (EDA)
# 1. **Gender Distribution**:
#    - There are more male employees (725) compared to female employees (475).
#
# 2. **Education Background**:
#    - The most common educational backgrounds among employees are Life Sciences (492) and Medical (384), followed by Marketing (137) and Technical Degree (100).
#
# 3. **Marital Status**:
#    - Majority of the employees are married (548), followed by single (384) and divorced (268).
#
# 4. **Employee Department**:
#    - The largest departments in terms of employee count are Sales (373), Development (361), and Research & Development (343), while departments like Data Science (20) and Finance (49) have fewer employees.
#
# 5. **Employee Job Role**:
#    - Common job roles include Sales Executive (270), Developer (236), Manager R&D (94), and Research Scientist (77).
#
# 6. **Business Travel Frequency**:
#    - Most employees travel rarely for business purposes (846), followed by frequent travelers (222), and those who do not travel at all (132).
#
# 7. **Overtime**:
#    - A majority of employees (847) do not work overtime, while a smaller proportion (353) do.
#
# 8. **Attrition**:
#    - The attrition rate is relatively low, with 1022 employees staying in the company (No) and 178 employees leaving (Yes).

# %%
df['PerformanceRating'].value_counts()
# Out:
# PerformanceRating
# 3    874
# 2    194
# 4    132
# Name: count, dtype: int64

# %%
df['PerformanceRating'].value_counts().plot.pie( autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Distribution of numerical data

# %%
numcols = [col for col in df.columns if df[col].dtype!='object']

# %%
fig = plt.figure(figsize = (18,12), facecolor='white')
for i, col in enumerate(numcols[:-1], start = 1):
    ax = fig.add_subplot(5,4,i)
    sns.histplot(x = df[col],kde = True, ax = ax)
     
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights
# 1. The majority of employees fall between the ages of **25** to **40**.
# 2. Majority of people commute less than **8 miles** to the office.
# 3. Majority of people whose education level is **3**.
# 4. Minimum hourly rate is **30** and maximmum is **100**.
# 5. Mojority of people whose NumCompaniesWorked is **1**.
# 6. Maximum and Minimum % of hikes are **12 and 24**, while most people having 12 and least people having 24% hikes.
# 7. Maximum people have **5 t0 15%** of experiance in this company.
# 8. most people have passed **1 year** since their last promotion

# %% [markdown]
# ### Pairplot
# TO find the relation between numerical continious data

# %%
# The dataset consists of descreate and comtinious data, now, we are finding relationships b/w continious data.
pairplot_cols = [col for col in numcols if df[col].nunique()>5]

# %%
plt.figure(figsize=(20, 25))
sns.pairplot(data=df[pairplot_cols])
plt.show()

# %% [markdown]
# ### Insights
# 1. **Age** is correlated with **'ExperienceYearsAtThisCompany', 'ExperienceYearsInCurrentRole','YearsSinceLastPromotion,'YearsWithCurrManager'

# %%
plt.figure(figsize=(16,18))
sns.heatmap(data = df[numcols].corr(), annot = True)
# Out:
# <Axes: >
